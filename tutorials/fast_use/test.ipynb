# %%
from weidmd import WeiDMD
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("prop-pol-1.dat")
time = data[:,0]
k1_real = data[:,1]
k1_imag = data[:,2]

# %%
num_snapshots=4000

# %%
DMD = WeiDMD(time,k1_real,num_snapshots=num_snapshots)

# %%
plt.figure(dpi=350)
DMD.fit(tf=1200,name='k1_real')
