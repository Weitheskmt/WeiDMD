# %%
# from weidmd.weidmd import WeiDMD
from weidmd import WeiDMD
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("./test_data/prop-pol-1.dat")
k1_time = data[:,0]
k1_real = data[:,1]
k1_imag = data[:,2]

# %%
DMD = WeiDMD(k1_time,k1_real,num_snapshots=600)

# %%
plt.figure(dpi=350)
time, kernel = DMD.fit(tf=1200,name='k',d=80)
plt.xlim(0,200)
# Out:
# *** d=80 ***
# *** MSE=2.2577417087015306e-06 ***
# *** If you want a smaller MSE, turn up d. ***
# (0.0, 200.0)
